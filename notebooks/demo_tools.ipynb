# %%
# Load libraries

import os
import json
import sys
from datetime import datetime
import logging

# Configure logging to show in console
logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s - %(name)s - %(levelname)s - %(message)s',
    handlers=[
        logging.StreamHandler(),  # This outputs to console
    ]
)

# Reload modules automatically when they change
# %load_ext autoreload
# %autoreload 2

# %%
cd ..
# Out:
# /Users/linafaik/Documents/projects/agentic-investor-brief

# %%
from agent_investor_brief.tools.industry_research import IndustryResearchTool
from agent_investor_brief.tools.financial_data import FinancialDataTool
# Out:
# 2025-09-30 23:02:07,918 - root - INFO - Environment setup completed
# 2025-09-30 23:02:07,919 - root - INFO - MLflow tracking: sqlite:///mlflow.db
# 2025-09-30 23:02:07,919 - root - INFO - Default model: gpt-5-nano
# 2025-09-30 23:02:07,921 - root - INFO - Output directory: outputs

# %%
ticker = "NVDA"

# %% [markdown]
# ## Financial Data Tool

# %%
financial_tool = FinancialDataTool()
financial_result = financial_tool._run(ticker)
financial_data = json.loads(financial_result)

financial_data
# Out:
# {'financial_summary': '## Financial Analysis: NVDA\n**Company**: NVIDIA Corporation\n**Sector**: Technology | **Industry**: Semiconductors\n\n### Current Trading Data\n- **Current Price**: $186.58\n- **Day Change**: 2.60%\n- **YTD Return**: 59.52%\n- **52W Range**: $86.61 - $187.35\n\n### Valuation Metrics\n- **P/E Ratio**: 52.1\n- **P/B Ratio**: 45.4\n- **PEG Ratio**: 0.0\n\n### Profitability\n- **Profit Margin**: 52.4%\n- **ROE**: 109.4%\n- **ROA**: 53.1%\n\n### Financial Performance (Latest Year)\n- **Revenue**: $130,497,000,000\n- **Net Income**: $72,880,000,000\n- **EPS**: $2.97\n\n### Analyst Outlook\n- **Recommendation**: STRONG_BUY\n- **Price Target**: $213.81\n- **Upside Potential**: 14.6%',
#  'detailed_data': {'ticker': 'NVDA',
#   'timestamp': '2025-09-30T23:02:07.983567',
#   'company_info': {'company_name': 'NVIDIA Corporation',
#    'sector': 'Technology',
#    'industry': 'Semiconductors',
#    'market_cap': 4542663491584,
#    'employees': 36000,
#    'country': 'United States',
#    'website': 'https://www.nvidia.com',
#    'business_summary': "NVIDIA Corporation, a computing infrastructure company, provides graphics and compute and networking solutions in the United States, Singapore, Taiwan, China, Hong Kong, and internationally. The Compute & Networking segment includes its Data Centre accelerated computing platforms and artificial intelligence solutions and software; networking; automotive platforms and autonomous and electric vehicle solutions; Jetson for robotics and other embedded platforms; and DGX Cloud computing services. The Graphics segment offers GeForce GPUs for gaming and PCs, the GeForce NOW game streaming service and related infrastructure, and solutions for gaming platforms; Quadro/NVIDIA RTX GPUs for enterprise workstation graphics; virtual GPU or vGPU software for cloud-based visual and virtual computing; automotive platforms for infotainment systems; and Omniverse software for building and operating industrial AI and digital twin applications. It also customized agentic solutions designed in collaboration with NVIDIA to accelerate enterprise AI adoption. The company's products are used in gaming, professional visualization, data center, and automotive markets. It sells its products to original equipment manufacturers, original device manufacturers, system integrators and distributors, independent software vendors, cloud service providers, consumer internet companies, add-in board manufacturers, distributors, automotive manufacturers and tier-1 automotive suppliers, and other ecosystem participants. NVIDIA Corporation was incorporated in 1993 and is headquartered in Santa Clara, California."},
#   'price_data': {'current_price': 186.5800018310547,
#    'previous_close': 181.8768,
#    'day_change': 2.601042380414646,
#    'volume': 235430647,
#    'avg_volume': 230306064,
#    '52_week_high': 187.35000610351562,
#    '52_week_low': 86.60909899272106,
#    'returns': {'1_day': 2.601042380414646,
#     '1_month': 9.257830443831704,
#     '3_months': 18.6585191298749,
#     'ytd': 59.51582369530756},
#    'volatility_30d': 31.62542190477548,
#    'beta': 2.102},
#   'financial_statements': {'income_statement': {'total_revenue': 130497000000.0,
#     'gross_profit': 97858000000.0,
#     'operating_income': 81453000000.0,
#     'net_income': 72880000000.0,
#     'ebitda': 86137000000.0,
#     'eps': 2.97},
#    'balance_sheet': {'total_assets': 111601000000.0,
#     'total_debt': 10270000000.0,
#     'total_equity': 79327000000.0,
#     'cash_and_equivalents': 8589000000.0,
#     'working_capital': 62079000000.0},
#    'cash_flow': {'operating_cash_flow': 64089000000.0,
#     'investing_cash_flow': -20421000000.0,
#     'financing_cash_flow': -42359000000.0,
#     'free_cash_flow': 60853000000.0,
#     'capital_expenditure': -3236000000.0}},
#   'key_metrics': {'valuation_metrics': {'pe_ratio': 52.11732,
#     'pb_ratio': 45.363483,
#     'ps_ratio': 27.494968,
#     'peg_ratio': 0.0,
#     'ev_ebitda': 44.492},
#    'profitability_metrics': {'profit_margin_pct': 52.414,
#     'operating_margin_pct': 60.842997,
#     'roe_pct': 109.417,
#     'roa_pct': 53.093999999999994,
#     'roic_pct': 0.0},
#    'financial_health': {'debt_to_equity': 10.584,
#     'current_ratio': 4.214,
#     'quick_ratio': 3.488,
#     'interest_coverage': 0.0},
#    'growth_metrics': {'revenue_growth_pct': 55.60000000000001,
#     'earnings_growth_pct': 61.199999999999996,
#     'book_value_growth_pct': 4.113},
#    'dividend_info': {'dividend_yield_pct': 2.0,
#     'payout_ratio_pct': 1.1400000000000001,
#     'dividend_rate': 0.04}},
#   'analyst_data': {'recommendation': 'strong_buy',
#    'target_price': 213.80856,
#    'target_high': 270.0,
#    'target_low': 100.0,
#    'analyst_count': 56,
#    'recommendation_mean': 1.35938},
#   'technical_indicators': {'moving_averages': {'sma_20': 175.9891098022461,
#     'sma_50': 177.0482290649414,
#     'sma_200': 142.2782702255249,
#     'price_vs_sma20': 6.017924654945561,
#     'price_vs_sma50': 5.3837153957733275},
#    'momentum_indicators': {'rsi': 62.216338804348304,
#     'macd': 1.8439219632690822,
#     'macd_signal': 0.9645704973507329,
#     'macd_histogram': 0.8793514659183493},
#    'trend_analysis': {'trend_direction': 'bullish', 'strength': 'strong'}}},
#  'data_quality': {'quality_score': 6,
#   'total_checks': 6,
#   'quality_percentage': 100.0,
#   'completeness': 'excellent',
#   'missing_data_areas': []},
#  'last_updated': '2025-09-30T23:02:07.983567'}

# %%
company_info = financial_data.get('detailed_data', {}).get('company_info', {})
company_info
# Out:
# {'company_name': 'NVIDIA Corporation',
#  'sector': 'Technology',
#  'industry': 'Semiconductors',
#  'market_cap': 4542663491584,
#  'employees': 36000,
#  'country': 'United States',
#  'website': 'https://www.nvidia.com',
#  'business_summary': "NVIDIA Corporation, a computing infrastructure company, provides graphics and compute and networking solutions in the United States, Singapore, Taiwan, China, Hong Kong, and internationally. The Compute & Networking segment includes its Data Centre accelerated computing platforms and artificial intelligence solutions and software; networking; automotive platforms and autonomous and electric vehicle solutions; Jetson for robotics and other embedded platforms; and DGX Cloud computing services. The Graphics segment offers GeForce GPUs for gaming and PCs, the GeForce NOW game streaming service and related infrastructure, and solutions for gaming platforms; Quadro/NVIDIA RTX GPUs for enterprise workstation graphics; virtual GPU or vGPU software for cloud-based visual and virtual computing; automotive platforms for infotainment systems; and Omniverse software for building and operating industrial AI and digital twin applications. It also customized agentic solutions designed in collaboration with NVIDIA to accelerate enterprise AI adoption. The company's products are used in gaming, professional visualization, data center, and automotive markets. It sells its products to original equipment manufacturers, original device manufacturers, system integrators and distributors, independent software vendors, cloud service providers, consumer internet companies, add-in board manufacturers, distributors, automotive manufacturers and tier-1 automotive suppliers, and other ecosystem participants. NVIDIA Corporation was incorporated in 1993 and is headquartered in Santa Clara, California."}

# %%
price_data = financial_data.get('detailed_data', {}).get('price_data', {})
price_data
# Out:
# {'current_price': 186.5800018310547,
#  'previous_close': 181.8768,
#  'day_change': 2.601042380414646,
#  'volume': 235430647,
#  'avg_volume': 230306064,
#  '52_week_high': 187.35000610351562,
#  '52_week_low': 86.60909899272106,
#  'returns': {'1_day': 2.601042380414646,
#   '1_month': 9.257830443831704,
#   '3_months': 18.6585191298749,
#   'ytd': 59.51582369530756},
#  'volatility_30d': 31.62542190477548,
#  'beta': 2.102}

# %%
print(financial_data["financial_summary"])
# Out:
# ## Financial Analysis: NVDA
# **Company**: NVIDIA Corporation
# **Sector**: Technology | **Industry**: Semiconductors
#
# ### Current Trading Data
# - **Current Price**: $186.58
# - **Day Change**: 2.60%
# - **YTD Return**: 59.52%
# - **52W Range**: $86.61 - $187.35
#
# ### Valuation Metrics
# - **P/E Ratio**: 52.1
# - **P/B Ratio**: 45.4
# - **PEG Ratio**: 0.0
#
# ### Profitability
# - **Profit Margin**: 52.4%
# - **ROE**: 109.4%
# - **ROA**: 53.1%
#
# ### Financial Performance (Latest Year)
# - **Revenue**: $130,497,000,000
# - **Net Income**: $72,880,000,000
# - **EPS**: $2.97
#
# ### Analyst Outlook
# - **Recommendation**: STRONG_BUY
# - **Price Target**: $213.81
# - **Upside Potential**: 14.6%

# %%
print(financial_data["data_quality"])
# Out:
# {'quality_score': 6, 'total_checks': 6, 'quality_percentage': 100.0, 'completeness': 'excellent', 'missing_data_areas': []}

# %% [markdown]
# ## Industry Research Tool

# %%
research_tool = IndustryResearchTool()
industry_result = research_tool._run(company_info["company_name"])
industry_data = json.loads(industry_result)

industry_data
# Out:
# {'research_summary': '# Industry Research Report: NVIDIA Corporation\n**Research Date:** 2025-09-30T23:03:45.366971\n**Total Sources:** 12\n\n## Recent Industry News\n**Nvidia spent over $900 million on Enfabrica CEO, AI ...**\nWhile Nvidia\'s earlier AI chips like the A100 were single processors slotted into servers, its most recent products come in tall racks with 72 GPUs installed working together. That\'s the kind of system inside the $4 billion data center in Wisconsin that Microsoft announced on Thursday. [...] On Thursday, Nvidia announced one of its most sizable investments to date. The chipmaker said it\'s taken a $5 billion stake in Intel, and announced that the two companies will collaborate on AI processors. Nvidia also said this week that it invested close to $700 million in U.K. data center startup Nscale.\n\n— Correction: A prior version of this story mistakenly included the name of a company as an investor in Enfabrica.\n\nWATCH: Nvidia CEO says he\'s delighted to work with Intel [...] Nvidia tried to buy chip design company Arm, but that deal collapsed in 2022 due to regulatory pressure. In the past year, Nvidia closed a $700 million purchase of Run:ai, an Israeli company whose technology helps software makers optimize their infrastructure for AI....\n*Source: https://www.cnbc.com/2025/09/18/nvidia-spent-over-900-million-on-enfabrica-ceo-ai-startup-technology.html*\n\n**NVIDIA Corp**\nU.S. equity funds attracted fresh cash in the week to September 24, snapping two-weeks of outflows, as risk sentiment improved following Nvidia’s announcement of a potential $100 billion investment in OpenAI.\n\nIllustration shows AI Artificial Intelligence words\n\nGlobal equity funds recorded net inflows for the first time in three weeks in the week to September 24, as optimism around artificial intelligence investments and renewed bets on potential U.S. rate cuts lifted investor sentiment. [...] Belgian chip research hub imec will appoint Patrick Vandenameele as its new chief executive with current CEO Luc Van den hove becoming chairman, the company told Reuters on Monday.\n\nReuters logo\n\nAll of the European Union\'s member states have entered a Dutch-led chips coalition that is pushing for revisions to the EU\'s Chips Act, the Dutch government said on Monday.\n\nEuropean Union flags flutter outside the EU Commission headquarters in Brussels [...] ## Browse World\n\n## Browse Business\n\n## Browse Markets\n\n## Browse Sustainability\n\n## Browse Legal\n\n## Browse Commentary\n\n## Browse Technology\n\n## Sports\n\n## Science\n\n## Lifestyle\n\n## City Memo\n\n## Graphics\n\n## Pictures\n\n## Wider Image\n\n## Podcasts\n\n## Live\n\n## Fact Check\n\n## Video\n\n## Sponsored Content\n\n# NVIDIA Corp\n\nMeta intends to acquire the chip startup Rivos to bolster its in-house semiconductor efforts, the social media company said on Tuesday.\n\nMeta Platforms\' corporate logo...\n*Source: https://www.reuters.com/company/nvidia-corp/*\n\n**NVDA.O - | Stock Price & Latest News**\nembedded platforms, and DGX Cloud computing services. The Graphics segment includes GeForce GPUs for gaming and PCs, the GeForce NOW game streaming service and related infrastructure, and solutions for gaming platforms; Quadro/NVIDIA RTX GPUs for enterprise workstation graphics; virtual GPU software for cloud-based visual and virtual computing; automotive platforms for infotainment systems, and Omniverse Enterprise software for building and operating industrial AI and digital twin applications. [...] NVIDIA Corporation is a full-stack computing infrastructure company. The Company is engaged in accelerated computing to help solve the challenging computational problems. The Company’s segments include Compute & Networking and Graphics. The Compute & Networking segment includes its Data Center accelerated computing platforms and artificial intelligence (AI) solutions and software; networking; automotive platforms and autonomous and electric vehicle solutions; Je ...
#  'total_sources': 12}

# %%
print(industry_data["research_summary"])
# Out:
# # Industry Research Report: NVIDIA Corporation
# **Research Date:** 2025-09-30T23:03:45.366971
# **Total Sources:** 12
#
# ## Recent Industry News
# **Nvidia spent over $900 million on Enfabrica CEO, AI ...**
# While Nvidia's earlier AI chips like the A100 were single processors slotted into servers, its most recent products come in tall racks with 72 GPUs installed working together. That's the kind of system inside the $4 billion data center in Wisconsin that Microsoft announced on Thursday. [...] On Thursday, Nvidia announced one of its most sizable investments to date. The chipmaker said it's taken a $5 billion stake in Intel, and announced that the two companies will collaborate on AI processors. Nvidia also said this week that it invested close to $700 million in U.K. data center startup Nscale.
#
# — Correction: A prior version of this story mistakenly included the name of a company as an investor in Enfabrica.
#
# WATCH: Nvidia CEO says he's delighted to work with Intel [...] Nvidia tried to buy chip design company Arm, but that deal collapsed in 2022 due to regulatory pressure. In the past year, Nvidia closed a $700 million purchase of Run:ai, an Israeli company whose technology helps software makers optimize their infrastructure for AI....
# *Source: https://www.cnbc.com/2025/09/18/nvidia-spent-over-900-million-on-enfabrica-ceo-ai-startup-technology.html*
#
# **NVIDIA Corp**
# U.S. equity funds attracted fresh cash in the week to September 24, snapping two-weeks of outflows, as risk sentiment improved following Nvidia’s announcement of a potential $100 billion investment in OpenAI.
#
# Illustration shows AI Artificial Intelligence words
#
# Global equity funds recorded net inflows for the first time in three weeks in the week to September 24, as optimism around artificial intelligence investments and renewed bets on potential U.S. rate cuts lifted investor sentiment. [...] Belgian chip research hub imec will appoint Patrick Vandenameele as its new chief executive with current CEO Luc Van den hove becoming chairman, the company told Reuters on Monday.
#
# Reuters logo
#
# All of the European Union's member states have entered a Dutch-led chips coalition that is pushing for revisions to the EU's Chips Act, the Dutch government said on Monday.
#
# European Union flags flutter outside the EU Commission headquarters in Brussels [...] ## Browse World
#
# ## Browse Business
#
# ## Browse Markets
#
# ## Browse Sustainability
#
# ## Browse Legal
#
# ## Browse Commentary
#
# ## Browse Technology
#
# ## Sports
#
# ## Science
#
# ## Lifestyle
#
# ## City Memo
#
# ## Graphics
#
# ## Pictures
#
# ## Wider Image
#
# ## Podcasts
#
# ## Live
#
# ## Fact Check
#
# ## Video
#
# ## Sponsored Content
#
# # NVIDIA Corp
#
# Meta intends to acquire the chip startup Rivos to bolster its in-house semiconductor efforts, the social media company said on Tuesday.
#
# Meta Platforms' corporate logo...
# *Source: https://www.reuters.com/company/nvidia-corp/*
#
# **NVDA.O - | Stock Price & Latest News**
# embedded platforms, and DGX Cloud computing services. The Graphics segment includes GeForce GPUs for gaming and PCs, the GeForce NOW game streaming service and related infrastructure, and solutions for gaming platforms; Quadro/NVIDIA RTX GPUs for enterprise workstation graphics; virtual GPU software for cloud-based visual and virtual computing; automotive platforms for infotainment systems, and Omniverse Enterprise software for building and operating industrial AI and digital twin applications. [...] NVIDIA Corporation is a full-stack computing infrastructure company. The Company is engaged in accelerated computing to help solve the challenging computational problems. The Company’s segments include Compute & Networking and Graphics. The Compute & Networking segment includes its Data Center accelerated computing platforms and artificial intelligence (AI) solutions and software; networking; automotive platforms and autonomous and electric vehicle solutions; Jetson for robotics and other [...] | Millions (USD) | 2025 | 2024 | 2023 |
#  ---  --- |
# | Total Assets | 111601 | 65728 | 41182 |
# | Total Debt | 8463 | 9709 | 10953 |
# | Total Liabilities | 32274 | 22750 | 19081 |
#
# 2025 (millions USD)
#
# ## Cash Flow
#
# | Millions (USD) | 2025 | 2024 | 2023 |
#  ---  --- |
# | Cash from Operating Activities | 64089 | 28090 | 5641 |
# | Financing Cash Flow Items | -7059 | -2858 | -1535 |
# | Cash from Investing Activities | -20421 | -10566 | 7375 |
#
# 2025 (millions USD)...
# *Source: https://www.reuters.com/markets/companies/NVDA.O*
#
# **Nvidia to invest up to $100 billion in OpenAI, linking two ...**
# ## Browse World
#
# ## Browse Business
#
# ## Browse Markets
#
# ## Browse Sustainability
#
# ## Browse Legal
#
# ## Browse Commentary
#
# ## Browse Technology
#
# ## Sports
#
# ## Science
#
# ## Lifestyle
#
# ## City Memo
#
# ## Graphics
#
# ## Pictures
#
# ## Wider Image
#
# ## Podcasts
#
# ## Live
#
# ## Fact Check
#
# ## Video
#
# ## Sponsored Content
#
# # Nvidia to invest up to $100 billion in OpenAI, linking two artificial intelligence titans
#
# Sign up  here.
#
# Illustration shows NVIDIA logo
#
# ## BROADER INDUSTRY MOVES [...] ### Workspace, opens new tab Access unmatched financial data, news and content in a highly-customised workflow experience on desktop, web and mobile.
#
# Access unmatched financial data, news and content in a highly-customised workflow experience on desktop, web and mobile.
#
# ### Data Catalogue, opens new tab Browse an unrivalled portfolio of real-time and historical market data and insights from worldwide sources and experts. [...] Nike on Tuesday reported a surprise rise in first-quarter revenue and beat expectations for quarterly profit as the sportswear giant rebuilds its presence at wholesalers and CEO Elliott Hill's turnaround efforts take hold.
#
# Logo of Amazon near Nantes
# Check-in counter at Spirit Airlines at Newark Liberty International Airport, in Newark, New Jersey
# Illustration shows U.S. dollar banknotes
# Pfizer research facility in California
#
# ## Site Index
#
# ## Browse
#
# ## About Reuters
#
# ## Stay Informed...
# *Source: https://www.reuters.com/business/nvidia-invest-100-billion-openai-2025-09-22/*
#
# **Nvidia and OpenAI's $100 Billion Virtuous Circle Has an ...**
# Nvidia is investing the sum in OpenAI as part of a build-out of data centers, potentially nabbing 2% of the company through the first $10 billion tranche. The circle continues with OpenAI pledging earlier this month to spend $300 billion on cloud compute from Oracle Corp., which also buys chips from Nvidia. Meanwhile, Nvidia is pouring $5 billion into Intel Corp., while OpenAI is formalizing a new corporate structure with its most important investor, Microsoft Corp. [...] The eye-popping partnership shows that AI’s real risk isn’t just a bursting bubble but industry consolidation that shuts out competitors.
#
# OpenAI And NVIDIA Announce Strategic Partnership
#
# Tech builders love a good feedback loop, and Nvidia Corp. and OpenAI have created a $100 billion one this week. [...] ### Industry Products
#
# ### Media
#
# ### Media Services
#
# ### Bloomberg
#
# Connecting decision makers to a dynamic network of information, people and ideas, Bloomberg quickly and accurately delivers business and financial information, news and insight around the world
#
# ### For Customers
#
# ### Support
#
# Americas+1 212 318 2000
#
# EMEA+44 20 7330 7500
#
# Asia Pacific+65 6212 1000
#
# # The $100 Billion Nvidia-OpenAI Virtuous Circle Has an Ugly Side...
# *Source: https://www.bloomberg.com/opinion/articles/2025-09-26/nvidia-and-openai-s-100-billion-virtuous-circle-has-an-ugly-side*
#
# ## Market Trends & Analysis
# **Why Nvidia Stock Skyrocketed 171.2% in 2024 but Is ...**
# | Fiscal Quarter | Wall Street Consensus Revenue Target | Actual Revenue | Percentage Beat |
#  ---  --- |
# | Q4 2024 | $20.62 billion | $22.1 billion | 7.2% |
# | Q1 2025 | $24.65 billion | $26.04 billion | 5.6% |
# | Q2 2025 | $28.7 billion | $30.04 billion | 4.7% |
# | Q3 2025 | $33.16 billion | $35.08 billion | 5.8% |
#
# Data sources: Nvidia and CNBC. [...] Price as of September 26, 2025, 3:59 p.m. ET
#
# Nvidia (NVDA 0.27%) stock posted another year of explosive gains in 2024. The company's share price closed out the year's trading up 171.2%, according to data from S&P Global Market Intelligence.
#
# NVDA data by YCharts [...] By Keith Noonan – Jan 13, 2025 at 3:12PM
#
# Key Points
#
#  Nvidia stock posted another year of fantastic gains in 2024.
#  Strong quarterly results, bullish Wall Street coverage, and a 10-for-1 stock split helped power big gains.
#  But the company's share price is down early in 2025's trading due to macroeconomic and geopolitical pressures.
#  Investor Alert: Our 10 best stocks to buy right now ›
#
# ## NASDAQ: NVDA
#
# ### Nvidia
#
# Market Cap
#
# $4.3T
#
# Today's Change
#
# (0.27%) $0.47
#
# Current Price
#
# $178.16...
# *Source: https://www.fool.com/investing/2025/01/13/why-nvidia-stock-skyrocketed-1712-in-2024-but-is-s/*
#
# **Nvidia Stock Is Up 187% in 2024, but Here's Another Super ...**
# Current Price
#
# $117.68
#
# Price as of May 14, 2025, 3:58 p.m. ET
#
# Advanced Micro Devices could disrupt Nvidia's dominance in the market for data center chips.
#
# Nvidia is the leading supplier of graphics processing units (GPUs) for data centers, which are used to develop artificial intelligence (AI) models. At the time of this writing, its stock has soared 187% year to date, because the company is delivering incredible revenue growth as chip demand continues to outstrip supply. [...] AMD's client segment revenue jumped 29% to $1.9 billion. It's home to the Ryzen AI chips, and considering Su believes the AI PC cycle is still in its infancy, investors should look for strong growth in this segment throughout 2025. [...] Published Time: 2024-12-05T09:23:00Z
#
# Nvidia Stock Is Up 187% in 2024, but Here's Another Super Semiconductor Stock to Buy in 2025, According to Wall Street | The Motley Fool
#
# Skip to main contentEnable accessibility for low visionOpen the accessibility menu
#
# Image 1: Spinner: White decorative
#
# Image 2
#
# Image 3: Spinner: White decorative
#
# ▲ S&P 500 +170% | ▲ Stock Advisor +948% Join The Motley Fool
#
# Accessibility Log In Help
#
# Accessibility Menu
#
# Image 4: The Motley Fool
#
# Our Services...
# *Source: https://www.fool.com/investing/2024/12/05/nvidia-stock-up-187-2024-stock-buy-2025-wall-stree/*
#
# **Nvidia: Undervalued At Current Levels, Poised For Multi- ...**
# Entering text into the input field will update the search result below
#
# Home page Seeking Alpha - Power to Investors
#
# Create free account
#
# Search for Symbols, analysts, keywords
#
# Log in
#
#
#
# Nvidia: Undervalued At Current Levels, Poised For Multi-Year Growth
#
# Sep. 12, 2025 8:45 AM ETNVIDIA Corporation (NVDA) Stock, NVDA:CA StockNVDA, NVDA:CA
#
# Image 1
#
# Steven Fiorillo
#
# 38.87K Follower s
#
# Follow
#
#    5 Share
#    Save
#    Play(16min)
#    Comments (55)
#
# Summary [...] NVIDIA Corporation is poised for further breakout, driven by sustained hyperscaler CapEx and unmatched revenue and profit growth.
#    NVDA's Q2 results showcased exceptional operational performance, with data center revenue up 56% YoY and profit margins exceeding 50%.
#    Despite concentration risks, NVDA's expansion into AI infrastructure and software platforms positions it for multi-year growth and recurring revenue....
# *Source: https://seekingalpha.com/article/4822373-nvidia-stock-undervalued-at-current-levels-poised-for-multi-year-growth*
#
# **Prediction: Nvidia Will Be Worth $15 Trillion by 2030 If This ...**
# By Keithen Drury – Sep 28, 2025 at 1:20PM
#
# Key Points
#
#  Nvidia is the world's leading GPU company, placing it at the foundation of the current AI megatrend.
#  Hyperscalers are mapping out their chip demand years in advance, shedding light on the scale of the opportunity for Nvidia.
#  Investor Alert: Our 10 best stocks to buy right now ›
#
# ## NASDAQ: NVDA
#
# ### Nvidia
#
# Market Cap
#
# $4.3T
#
# Today's Change
#
# (0.27%) $0.47
#
# Current Price
#
# $178.16
#
# Price as of September 26, 2025, 3:59 p.m. ET [...] Over the past 12 months, Nvidia's revenue totaled $165 billion, and it's still growing at a rapid pace. Wall Street analysts project that in the current fiscal year (ending Jan. 2026), Nvidia's top line will hit $206 billion, but even that amount is nothing compared to where management believes the business could go by fiscal 2030.
#
# Data by YCharts. [...] While some investors may be quick to write off this massive market projection, data centers take years to build. The process includes identifying a location, sourcing power, designing the facility, building it, and outfitting it with computing equipment. This means many of the data centers companies are announcing plans for in 2025 won't be operating until 2026 and beyond. So AI hyperscalers (and other big enterprise buyers) must coordinate chip supply with Nvidia. Otherwise, they could face...
# *Source: https://www.fool.com/investing/2025/09/28/prediction-nvidia-will-be-worth-15-trillion-by-203/*
#
# ## Competitive Landscape
# **Nvidia Market share relative to its competitors, as of Q2 2025**
# *   [Company Profile](https://csimarket.com/stocks/at_glance.php?code=NVDA) *   [Nvidia Corp News](https://csimarket.com/stocks/news.php?code=NVDA) *   [Nvidia Corp Growth Rates](https://csimarket.com/stocks/growthrates.php?code=NVDA) *   [Nvidia Corp Profitability](https://csimarket.com/stocks/Profitability.php?code=NVDA) *   [Nvidia Corp Business Segments](https://csimarket.com/stocks/segments.php?code=NVDA) *   [Suppliers](https://csimarket.com/stocks/suppliers_glance.php?code=NVDA) *   [Nvidia Corp Suppliers Performance](https://csimarket.com/stocks/competition2.php?supply&code=NVDA) *   [NVDA Suppliers Data](https://csimarket.com/stocks/competitionNO4.php?supply&code=NVDA) *   [Nvidia Corp Market Share](https://csimarket.com/stocks/competitionSEG2.php?code=NVDA) *   [Nvidia Corp Competition Performance](https://csimarket.com/stocks/competitionNO9.php?code=NVDA) *   [Nvidia Corp Competitors Results](https://csimarket.com/stocks/competition2.php?code=NVDA) *   [Customers&Markets](https://csimarket.com/stocks/markets_glance.php?code=NVDA) *   [Nvidia Corp Customers Demand](https://csimarket.com/stocks/custexNO.php?markets&code=NVDA) *   [NVDA Customers Growth Rates](https://csimarket.com/stocks/competitionNO3.php?markets&code=NVDA) *   [NVDA Customers Efficiency](https://csimarket.com/stocks/competitionNO5.php?markets&code=NVDA) *   [NVDA Customers Valuation](https://csimarket.com/stocks/competitionNO8.php?markets&code=NVDA) *   [Charts&Quotes](https://csimarket.com/stocks/charts.php?code=NVDA) *   [Nvidia Corp Comparison Charts](https://csimarket.com/stocks/technicals_compare.php?code=NVDA) *   [Nvidia Corp's Profile](https://csimarket.com/stocks/at_glance.php?code=NVDA) *   [Company Charts and Quotes](https://csimarket.com/stocks/charts.php?code=NVDA) *   [Nvidia Corp News](https://csimarket.com/stocks/news.php?code=NVDA) *   [Nvidia Corp's Profitability](https://csimarket.com/stocks/Profitability.php?code=NVDA) *   [Nvidia Corp's Financials](https://csimarket.com/stocks/financials_glance.php?code=NVDA) *   [Nvidia Corp's Suppliers](https://csimarket.com/stocks/suppliers_glance.php?code=NVDA) *   [Nvidia Corp's Competitors](https://csimarket.com/stocks/compet_glance.php?code=NVDA) *   [Nvidia Corp's Markets&Customers](https://csimarket.com/stocks/markets_glance.php?code=NVDA) *   [Nvidia Corp's Market Share](https://csimarket.com/stocks/competitionSEG2.php?code=NVDA) *   [](https://csimarket.com/stocks/competitionSEG2.php?code=NVDA) *   [](https://csimarket.com/stocks/competitionSEG2.php?code=NVDA "Facebook")   *   [](https://csimarket.com/stocks/competitionSEG2.php?code=NVDA "LinkedIn Company")  ...
# *Source: https://csimarket.com/stocks/competitionSEG2.php?code=NVDA*
#
# **NVDA NVIDIA Corporation Peers & Competitors**
# Entering text into the input field will update the search result below Entering text into the input field will update the search result below Search for Symbols, analysts, keywords # NVDA NVIDIA Corporation Peers & Competitors |  | NVDA AVGO TSM AMD QCOM MU | Company Name | NVIDIA Corporation Broadcom Inc. Taiwan Semiconductor Manufacturing Company Limited Advanced Micro Devices, Inc. QUALCOMM Incorporated Micron Technology, Inc. | Sector | Information Technology Information Technology Information Technology Information Technology Information Technology Information Technology | Industry | Semiconductors Semiconductors Semiconductors Semiconductors Semiconductors Semiconductors | SA Analysts Covering | 51 31 11 25 15 20 | Wall St. Analysts | 64 45 16 52 36 38 ## Dividends Plus, stay informed with unlimited breaking news—now completely free....
# *Source: https://seekingalpha.com/symbol/NVDA/peers/comparison*
#
# **Biggest competitors of NVIDIA? : r/ArtificialInteligence**
# We all know thatNvidia has about 80% market share in the semi conductor marketand that competition is slowly creeping up from companies like AMD and Intel....
# *Source: https://www.reddit.com/r/ArtificialInteligence/comments/1gywtgz/biggest_competitors_of_nvidia/*
